# %%
from matplotlib import pyplot as plt

sizes = [100, 250, 500, 1000, 5000, 10000, 100000]
time_linear = [3.2400013878941536e-05, 6.019999273121357e-05, 0.0001221999991685152, 0.00024070008657872677, 0.0012065998744219542, 0.0027852000202983618, 0.027402899926528335]
time_binary = [8.299946784973145e-06, 8.400063961744308e-06, 8.600065484642982e-06, 9.799841791391373e-06, 1.910002902150154e-05, 1.500011421740055e-05, 2.010003663599491e-05]
time_binary_sort = [0.0005946999881416559, 0.0015356999356299639, 0.0031229001469910145, 0.00612060003913939, 0.04119469993747771, 0.09977480000816286, 1.4874442999716848]
time_key = [6.729993037879467e-05, 3.350013867020607e-05, 2.4499837309122086e-05, 6.949994713068008e-05, 0.0003986000083386898, 0.003581400029361248, 0.009184699971228838]

plt.plot(sizes, time_linear, label='Прямой поиск')
plt.plot(sizes, time_binary, label='Бинарный поиск')
plt.plot(sizes, time_binary_sort, label='Быстрая сортировка и бинарный поиск')
plt.plot(sizes, time_key, label='Поиск по ключу')
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()

# %%
plt.plot(sizes, time_linear, label='Прямой поиск')
plt.plot(sizes, time_binary, label='Бинарный поиск')
plt.plot(sizes, time_key, label='Поиск по ключу')
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время сортировки", alpha=0.5)
plt.legend()
plt.show()
